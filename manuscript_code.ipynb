# %%
import os
import re
import pandas as pd
import numpy as np
import nilearn
from nilearn import datasets, surface
import nibabel as nib
from neuromaps import transforms
from scipy.stats import zscore, spearmanr
import matplotlib.pyplot as plt
import matplotlib.cm as cm
from palettable.matplotlib.colormaps import _VIRIDIS_DATA
import seaborn as sns
from sklearn.manifold import MDS
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_samples, silhouette_score
from statsmodels.stats.multitest import fdrcorrection
from brainspace.datasets import load_parcellation, load_conte69
from brainspace.plotting import plot_hemispheres
from brainspace.utils.parcellation import map_to_labels 
from brainspace.null_models import SpinPermutations, SurrogateMaps
from enigmatoolbox import datasets
import enigmatoolbox as etb
from enigmatoolbox.utils.parcellation import parcel_to_surface
from enigmatoolbox.plotting import plot_subcortical
from palettable.cartocolors.qualitative import Vivid_4
from wordcloud import WordCloud
surf_lh, surf_rh = load_conte69()
inpath='/path/to/input' #specify your input path here
outpath='/path/to/output'  # specify your output path here

# %%
#KIDB preprocessing
ki_database=pd.read_csv('KiDatabase.csv', encoding='mac-roman', usecols=['Name','Unigene',' Ligand Name','species','source', 'ki Note','ki Val', 'Reference'])
ki_database_human=ki_database[ki_database['species'] == 'HUMAN']
def data_driven_selector(inp):
    ki_database_human=inp
    #standardize input and filter for >
    ki_database_human[' Ligand Name']=ki_database_human[' Ligand Name'].str.capitalize()
    ki_database_human=ki_database_human[ki_database_human['ki Note'] != '>']
    ki_database_human=ki_database_human[ki_database_human['ki Val'] < 10000]
    substances=['Agomelatine', 'Amitriptyline', 'Bupropion', 'Citalopram',
       'Clomipramine', 'Desvenlafaxine', 'Duloxetine', 'Escitalopram',
       'Fluoxetine', 'Fluvoxamine', 'Milnacipran', 'Mirtazapine',
       'Nefazodone', 'Paroxetine', 'Reboxetine', 'Sertraline',
       'Trazodone', 'Venlafaxine']
    d={substance:{} for substance in substances}
    for substance in substances:
        subset=ki_database_human[ki_database_human[' Ligand Name'] == substance]
        molecules=np.unique(subset['Name'])
        for molecule in molecules:
            d[substance][molecule]=np.mean(subset[subset['Name'] == molecule]['ki Val'])
    return d

d=data_driven_selector(ki_database_human)
dd_ad=pd.DataFrame(d)

#manual unification
synonyms_dict={'5-HTT':['5-HT Transporter','SERT'], '5-HT1A':['5-HT1A'],'5-HT1B':['5-HT1B'],
              '5-HT2A':['5-HT2A', '5-HT2'], '5-HT2B':['5-HT2B', '5-HT2'], '5-HT2C':['5-HT2C', '5-HT2'],
               '5-HT6':['5-HT6'],'NET':['Norepinephrine transporter'],
               'alpha1':['Alpha 1 Adrenergic Receptor', 'adrenergic Alpha1', 'adrenergic Alpha1A'],
              'alpha2':['Alpha 2 Adrenergic Receptor', 'adrenergic Alpha2', 'adrenergic Alpha2A','adrenergic Alpha2B','adrenergic Alpha2C'],
              'DAT':['Dopamine Transporter'], 'D1':['DOPAMINE D1','D1'],'D2':['DOPAMINE D2','D2'],
              'D3':['DOPAMINE D3','D3'], 'D4':['DOPAMINE D4','D4'], 'D5':['DOPAMINE D5'],
              'H1':['HISTAMINE H1', 'H1'],'H2':['HISTAMINE H2', 'H2'], 'H3':['HISTAMINE H3', 'H3'],
              'H4':['HISTAMINE H4', 'H4'],
               'M1':['Muscarinic Acetylcholine Receptor','Cholinergic, muscarinic','Cholinergic, muscarinic M1'],
              'M2':['Muscarinic Acetylcholine Receptor','Cholinergic, muscarinic','Cholinergic, muscarinic M2'],
              'M3':['Muscarinic Acetylcholine Receptor','Cholinergic, muscarinic','Cholinergic, muscarinic M3'],
              'M4':['Muscarinic Acetylcholine Receptor','Cholinergic, muscarinic','Cholinergic, muscarinic M4'],
              'M5':['Muscarinic Acetylcholine Receptor','Cholinergic, muscarinic','Cholinergic, muscarinic M5']}
unified={unificator:{} for unificator in synonyms_dict.keys()}
for key, val in synonyms_dict.items():
    extract=dd_ad.T[val].T.mean()
    unified[key]=dict(extract)

dd_unified=pd.DataFrame(unified)
dd_unified.fillna(value=10000, inplace=True) #fill missing data and cap Ki values at 10000
#dd_unified.to_csv('kidb_ad.csv')

# %%
#load data
#antidepressant data
dd_unified=pd.read_csv('kidb_ad.csv', index_col=0) #Inhibition coefficients from human sources averaged across KiDB entries per target
cipriani=pd.read_csv('efficacy_data.csv', index_col=0) #Efficacy data from https://doi.org/10.1016/s0140-6736(17)32802-7

#neurochemistry
#receptors_schaefer=pd.read_csv('400Parcels7Networks_NTRM.csv', index_col=0) #Chemoarchitectural data as described in https://doi.org/10.7554/eLife.83843

#enigma
## load summary statistics for cortical thickness variation in adult samples and make into df
d={}
sum_stats=etb.datasets.load_summary_stats('depression')
CT=sum_stats['CortThick_case_vs_controls_adult']
CT=CT['d_icv']
d['depression_all']=CT
enigma_df=pd.DataFrame(d)

#annotations
networks=np.load('yeo_400parc.npy') #7 Yeo networks in 400 Schaefer parcels as per https://doi.org/10.1093/cercor/bhx179
types_400=np.load('mesulam_400_parcels.npy') #Division of the cortex into four cortical types by Mesulam as per https://doi.org/10.1093/brain/121.6.1013

# %%
#Figure 1A
sns.set(font_scale=2.55, style='white')
fig=sns.clustermap(np.log(dd_unified), method='ward', figsize=(18,14), tree_kws=dict(linewidths=1.6)) #perform hierarchical agglomerative clustering on log-transformed KiDB-derived affinity profiles using ward's linkage algorithm
fig.tick_params(labelsize=34)
fig.savefig(outpath + 'FIG_1A.jpeg')
plt.close()

#Cluster validation supplement - supplementary figures 3 and 4
##replicate the analysis using different linkage algorithms and non-log-transformed Ki values
for i in ['single','complete','average','weighted','centroid','median','ward']:
    for j,k in enumerate([np.log(dd_unified), dd_unified]):
        fig = sns.clustermap(k, method=i, figsize=(18,14), tree_kws=dict(linewidths=1.6))
        plt.tight_layout()
        if j == 0:
            fig.savefig(outpath + 'ClusVal_log_{}.jpeg'.format(i))
            plt.close()
        else:
            fig.savefig(outpath + 'ClusVal_nolog_{}.jpeg'.format(i))
            plt.close()

# %%
#Figure 1B
##perform KMeans clustering on log-transformed KiDB-derived affinity profiles using three centroids as indiated by silhouette score (supplement)
X=np.log(dd_unified).values
kmeans = KMeans(n_clusters=3, random_state=0, init='k-means++', n_init=10).fit(X) 
color_dict={0 : 'cyan', 1 : 'y', 2 : 'violet'}
colors=[color_dict[i] for i in kmeans.labels_]
mds=MDS(random_state=1)
mds_fit=mds.fit_transform(np.log(dd_unified))
sns.set_style('white')
fig, ax=plt.subplots(figsize=(18,14))
plt.scatter(mds_fit[:,0], mds_fit[:,1], s=320, c=colors)
labels_list=['AGO', 'AMI', 'BUP', 'CIT', 'CLO', 'DVEN', 'DUL', 'ECIT', 'FLUO','FLUV','MIL','MIR','NEF','PAR','REB','SER',
            'TRA','VEN']
ax.set_ylabel('Dimension 2', fontsize=38)
ax.set_xlabel('Dimension 1', fontsize=38)
ax.tick_params(labelsize=32)
for i, txt in enumerate(labels_list):
    ax.annotate(txt, (mds_fit[i,0], mds_fit[i,1]), fontsize=32)
plt.tight_layout()
fig.savefig(outpath + 'FIG_1B.jpeg')
plt.close()

# %%
# Figure 1C
##Correlate mean efficacy as per Cipriani et al (https://doi.org/10.1016/S0140-6736(17)32802-7) with Ki values from KiDB for all substances
combined=dd_unified.merge(cipriani, left_index=True, right_on='compound')
corr, pval=spearmanr(dd_unified, combined['efficacy'])
print('fdr-corrected statistical significance at alpha = 0.05 using the benjamini-hochberg method:')
print(list(zip(dd_unified.columns, fdrcorrection(pval[-1])[1])))
sns.set_style('ticks')
fig, ax = plt.subplots(figsize=(30,8))
interest=corr[-1][:-1]
color=['lightskyblue' if x > 0.05 else 'dodgerblue' for x in pval[-1][:-1]]
ax.bar(range(len(interest)), interest, color=color, width=0.9, linewidth=1)
ax.set_xticks(range(len(interest)))
ax.set_xticklabels(dd_unified.columns, rotation=45, ha='center')
ax.set_ylabel("spearman's r", fontsize=36)
ax.tick_params(labelsize=36)
plt.tight_layout()
fig.savefig(outpath + 'FIG_1C.jpeg')
plt.close()

# %%
# Figure 2A and Supplementary Figure 4B
##generate drug action value distribution profiles in the cortical surface using the max overlap of available receptor/transporter densities and KiDB-derived affinity profiles, where the respective affinity for receptor x weights the influence receptor x has on the total regional value
labeling = load_parcellation('schaefer', scale=400, join=True)
labels_list=['AGO', 'AMI', 'BUP', 'CIT', 'CLO', 'DVEN', 'DUL', 'ECIT', 'FLUO','FLUV','MIL','MIR','NEF','PAR','REB','SER',
            'TRA','VEN']
affi_max=dd_unified[['5-HTT','NET','DAT','5-HT1A','5-HT1B','5-HT2A','5-HT6','D1','D2', 'M1','H3']]
max_overlap=receptors_schaefer[['5HTT','NAT','DAT','5HT1a','5HT1b','5HT2a','5HT6','D1','D2','M1','H3']]
fact=1 / affi_max #use fraction of ki value for weighting since low Ki value represents high affinity
fact=fact.values
red_rec_array=max_overlap.values
weighted_total=red_rec_array @ fact.T
weighted_total_df=pd.DataFrame(weighted_total, index=max_overlap.index, columns=affi_max.index)
weighted_total_df.index=networks
weighted_total_z=weighted_total_df.apply(zscore)
for i in range(len(weighted_total[0])):
    interest=weighted_total[:,i]
    label=labels_list[i]
    grad1_100=map_to_labels(interest, labeling, mask=labeling != 0, fill=np.nan)
    plot_hemispheres(surf_lh, surf_rh, array_name=grad1_100, size= (1000,600),color_bar=True, label_text=[label],zoom=1.4, nan_color=(0,0,0,0),
                      layout_style='grid', 
                 cmap='viridis', screenshot=True, transparent_bg = True, filename=outpath + 'FIG_2A_{}_400.png'.format(label))

# %%
# Figure 2B
##analyse and plot the distribution of drug action values across the two pre-specified neuroanatomical modes
sns.set_style('ticks')
yeo_colours = np.array([[120 ,18 ,134],[ 70, 130, 180],[ 0, 118, 14],[196, 58, 250],[ 220, 248, 164],[230, 148, 34,], [205, 62, 78]]) / 256
for i in ['Amitriptyline','Mirtazapine','Duloxetine']:
    fig, ax=plt.subplots(figsize=(8,6))
    sns.boxplot(data=weighted_total_z, x=weighted_total_df.index, y=i, palette=yeo_colours)
    ax.set_xticklabels(['vis','som-\nmot','dors\natt','vent\natt','limb','cont','def'])
    ax.tick_params(labelsize=26)
    ax.set_ylabel(i, fontsize=26)
    ax.set_xlabel('')
    plt.tight_layout()
    fig.savefig(outpath + 'FIG_2B_FC_{}_400.jpeg'.format(i))
    plt.close()

weighted_total_z['Mesulam']=types_400
col_types={'paralimbic':Vivid_4.mpl_colors[3],'unimodal':Vivid_4.mpl_colors[1],
          'idiotypic':Vivid_4.mpl_colors[0],'heteromodal':Vivid_4.mpl_colors[2]}
for i in ['Amitriptyline','Mirtazapine','Duloxetine']:
    fig, ax=plt.subplots(figsize=(8,6))
    sns.boxplot(y=i, x='Mesulam', data=weighted_total_z, order=['idiotypic','unimodal',
                                                               'heteromodal','paralimbic'], palette=col_types ,width=0.65)
    ax.set_xticks([0,1,2,3])
    ax.tick_params(labelsize=26)
    ax.set_xticklabels(['idio-\ntypic','uni-\nmodal','hetero-\nmodal','para-\nlimbic'])
    ax.tick_params(labelsize=26)
    ax.set_ylabel(i, fontsize=26)
    ax.set_xlabel('')
    plt.tight_layout()
    fig.savefig(outpath + 'FIG_2B_CT_{}_400.jpeg'.format(i))
    plt.close()

# %%
# Figure 2C
##analyse and plot the correlation between drug distribution profiles and disease-associated cortical thickness changes in depression
fsavg=nilearn.datasets.fetch_surf_fsaverage('fsaverage5')
sphere_lh_fs=nilearn.surface.load_surf_mesh(fsavg['sphere_left'])[0]
sphere_rh_fs=nilearn.surface.load_surf_mesh(fsavg['sphere_right'])[0]
sp_fs = SpinPermutations(n_rep=1000, random_state=0)
sp_fs.fit(sphere_lh_fs, points_rh=sphere_rh_fs)

"""
Spin function code adapted from:
https://brainspace.readthedocs.io/en/latest/python_doc/auto_examples/plot_tutorial3.html
"""


def spin(inp, grad, spin_grad):
    r_spin = np.empty(1000)
    mask = ~np.isnan(grad) & ~ np.isnan(inp)
    r_obs = spearmanr(grad[mask], inp[mask])[0]
    #print(r_obs)
    for i, perm in enumerate(spin_grad):
        mask_rot = mask & ~np.isnan(perm)  # Remove midline
        r_spin[i] = spearmanr(perm[mask_rot], inp[mask_rot])[0]
    pv_spin = np.mean(np.abs(r_spin) >= np.abs(r_obs))
    return [r_obs, pv_spin]

def permute(inp):
    half=int(len(inp) / 2)
    left=inp[half:]
    right=inp[:half]
    return np.hstack(sp_fs.randomize(left, right))

enigma_surf=parcel_to_surface(enigma_df['depression_all'], 'aparc_fsa5')
enigma_surf=np.where(enigma_surf == 0, np.NaN, enigma_surf)
permuted=permute(enigma_surf)
result_dk_schaefer={}
for i in weighted_total_df.columns:
    substance=weighted_total_df[i].values
    substance_surf=parcel_to_surface(substance, 'schaefer_400_fsa5')
    substance_surf=np.where(substance_surf == 0, np.NaN, substance_surf)
    result_dk_schaefer[i]=spin(substance_surf, enigma_surf, permuted)
pvals=np.array(list(result_dk_schaefer.values()))[:,1]
print('fdr-corrected statistical significance at alpha = 0.05 using the benjamini-hochberg method:')
print(list(zip(dd_unified.index, fdrcorrection(pvals)[1])))


sns.set_style('ticks')
fig, ax = plt.subplots(figsize=(6,14))

plotting=pd.DataFrame(result_dk_schaefer).T
spear=list(plotting[0])[::-1]
pval=list(plotting[1])[::-1]
color=['lightskyblue' if x > 0.05 else 'dodgerblue' for x in pval]

ax.barh(range(len(plotting)), width=spear, color=color)
ax.set_yticks(range(len(plotting)))
ax.set_yticklabels(labels_list[::-1])
ax.set_xlabel("spearman's r", fontsize=32)
ax.tick_params(labelsize=32)
ax.set_xlim(-0.5, 0.35)
plt.tight_layout()
fig.savefig(outpath + 'FIG_2C_400.jpeg')
plt.close()

# %%
#Figure 2D
##analyse and plot the correlation between drug distribution profiles and meta-analytical topic-based activation maps
def adjusted_spin(inp, grad, spin_grad): #define adjusted spin function that removes midline vertices from the null distribution based on only one mask
    r_spin = np.empty(1000)
    mask = ~np.isnan(grad) 
    r_obs = spearmanr(grad[mask], inp[mask])[0]
    for i, perm in enumerate(spin_grad):
        mask_rot = mask & ~np.isnan(perm)  # Remove midline
        r_spin[i] = spearmanr(perm[mask_rot], inp[mask_rot])[0]
    pv_spin = np.mean(np.abs(r_spin) >= np.abs(r_obs))
    return [r_obs, pv_spin]


nsynth_path='/path/to/neurosynth/'
files=os.listdir(nsynth_path)
pattern=re.compile('LDA50_abstract_weight__(.*)_z_desc-specificity.nii.gz')
select=[]
substances_on_surf={}
substances_on_surf_permuted={}
for i in ['Amitriptyline','Mirtazapine','Duloxetine']:
    substance=weighted_total_df[i].values
    substance_surf=parcel_to_surface(substance, 'schaefer_400_fsa5')
    substance_surf=np.where(substance_surf == 0, np.NaN, substance_surf)
    substances_on_surf[i]=substance_surf
    substances_on_surf_permuted[i]=permute(substance_surf)
for i in files:
    s=re.match(pattern, i)
    if s is not None:
        select.append(s)

result_nimare_schaefer_400={'Amitriptyline':{}, 'Mirtazapine':{}, 'Duloxetine':{}}

select_subset=select[:2]
for i in select:
    term=i.group(1)
    img=nib.load(nsynth_path + "LDA50_abstract_weight__{}_z_desc-specificity.nii.gz".format(term))
    img_fs=transforms.mni152_to_fsaverage(img, '10k')
    fs_lh, fs_rh = img_fs
    fs_both=np.concatenate([fs_lh.agg_data(), fs_rh.agg_data()])
    for substance in ['Amitriptyline','Mirtazapine','Duloxetine']:
        result_nimare_schaefer_400[substance][term]=adjusted_spin(fs_both, substances_on_surf[substance],  substances_on_surf_permuted[substance])
for key, value in result_nimare_schaefer_400.items():
    plotting=pd.DataFrame(value).T
    plotting.columns=["Spearman's r", 'p-value']
    thresholded=plotting[plotting['p-value'] < 0.05]
    wc = WordCloud(background_color="white", random_state=0, width=800, height=500)
    copy=thresholded.copy()
    copy["Spearman's r"]=np.abs(copy["Spearman's r"])
    wc.generate_from_frequencies(frequencies=copy.to_dict()["Spearman's r"])
    def color_funcs(word, *args, **kwargs):
        if thresholded["Spearman's r"].T[word] <=0:
            color = tuple(_VIRIDIS_DATA[1])
        else:
            color = tuple(_VIRIDIS_DATA[-60])
        return color
    wc.recolor(color_func=color_funcs)
    wc.to_file(outpath + 'wc{}_400.png'.format(key))

# %%
# Figure 3
# 3A - make subcortical drug distribution profiles and plot them in heatmap format

sns.set_style('ticks')
subcortex=pd.read_csv('receptors_subcortex_all.csv', index_col=0) 

order_enigmatoolbox=['Accumbens-left', 'Amygdala-left','Caudate-left','Hippocampus-left','Pallidum-left','Putamen-left', 'Thalamus-left','Accumbens-right', 'Amygdala-right','Caudate-right','Hippocampus-right','Pallidum-right','Putamen-right', 'Thalamus-right']
subcortex_reordered=subcortex.T[order_enigmatoolbox].T

labels_list=['AGO', 'AMI', 'BUP', 'CIT', 'CLO', 'DVEN', 'DUL', 'ECIT', 'FLUO','FLUV','MIL','MIR','NEF','PAR','REB','SER',
            'TRA','VEN']
affi_max=dd_unified[['5-HTT','NET','DAT','5-HT1A','5-HT1B','5-HT2A','5-HT6','D1','D2', 'M1','H3']]
max_overlap=subcortex_reordered[['5HTT','NAT','DAT','5HT1a','5HT1b','5HT2a','5HT6','D1','D2','M1','H3']]
fact=1 / affi_max
fact=fact.values
red_rec_array=max_overlap.values
weighted_total_subcortex=red_rec_array @ fact.T
weighted_total_df_subcortex=pd.DataFrame(weighted_total_subcortex, index=max_overlap.index, columns=affi_max.index)

#subcortex

zscored_binding=weighted_total_df_subcortex.apply(zscore) 
ad_order=['Amitriptyline','Clomipramine','Mirtazapine','Nefazodone','Trazodone','Agomelatine',
                            'Bupropion','Reboxetine','Milnacipran','Desvenlafaxine','Fluvoxamine','Paroxetine','Sertraline',
                            'Duloxetine','Citalopram','Escitalopram','Fluoxetine','Venlafaxine']
for_heatmap=zscored_binding[ad_order].T

heatmap_order=['Accumbens-left','Accumbens-right','Caudate-left','Caudate-right','Putamen-left',
                         'Putamen-right','Pallidum-left','Pallidum-right',
                        'Thalamus-left','Thalamus-right','Hippocampus-left','Hippocampus-right','Amygdala-left','Amygdala-right']

for_heatmap=for_heatmap[heatmap_order]

heatmap_labels_structures=['ACU-L','ACU-R','CAU-L','CAU-R','PUT-L','PUT-R','PAL-L','PAL-R','THA-L','THA-R','HIP-L','HIP-R','AMY-L','AMY-R']
heatmap_labels_ad=['AMI','CLO','MIR','NEF','TRA','AGO','BUP','REB','MIL','DVEN','FLUV','PAR','SER','DUL','CIT','ECIT','FLUO','VEN']


fig, ax = plt.subplots(figsize=(8,10))
sns.heatmap(for_heatmap, cmap='viridis')
ax.set_xticks(np.arange(len(heatmap_labels_structures)) + 0.5)
ax.set_xticklabels(heatmap_labels_structures, fontsize=24,rotation=90+90+90+20)
ax.set_yticklabels(heatmap_labels_ad, fontsize=24)
plt.tight_layout()
fig.savefig(outpath + 'heatmap_subcortex.jpeg')

#3B - visualise drug distribution profiles on subcortical structures

for substance in weighted_total_df.columns:
    plot_subcortical(zscored_binding[substance], ventricles=False, screenshot=True, transparent_bg=False, background=(255,255,255), size=(1000,400), zoom=1.4, color_bar=True, cmap='viridis',
                     label_text=[labels_list[i]], filename= outpath + '{}_1.jpeg'.format(substance), cmap='viridis')


# 3C - analyse and plot correlation between subcortical drug action values and disease-associated subcortical volume associations in depression

"""
Surrogate maps code adapted from:
https://brainspace.readthedocs.io/en/latest/python_doc/auto_examples/plot_tutorial3.html
"""

sum_stats=etb.datasets.load_summary_stats('depression')
sc_vol=sum_stats['SubVol_case_vs_controls']
sc_vol.drop(labels=[7,15], inplace=True)
plot_subcortical(array_name=sc_vol['d_icv'], size=(800, 400),
                 cmap='RdBu_r', color_bar=False, embed_nb=True, transparent_bg=False, background=(255,255,255), screenshot=True, ventricles=False, zoom=1.4,
                 filename=outpath + 'subcortical_depression.jpeg')


n_surrogate_datasets = 1000

# Note: number samples must be greater than number neighbors
num_samples = 100
num_neighbors = 50
sc_distances=np.load('euclidean_dist_aseg.npy')
ssm = SurrogateMaps(random_state=0)
ssm.fit(sc_distances)

enigma_sc_surrogates = ssm.randomize(sc_vol['d_icv'].values, n_rep=n_surrogate_datasets)

surrogate_corr_dict={}
pvals=[]
for substance in weighted_total_df_subcortex.columns:
    interest=weighted_total_df_subcortex[substance]
    r_obs, pv_obs = spearmanr(interest, sc_vol['d_icv'].values, nan_policy='omit')
    r_rand=np.empty(n_surrogate_datasets)
    for entry in range(n_surrogate_datasets):
        r_rand[entry]=spearmanr(interest, enigma_sc_surrogates[entry])[0]
    pv_rand = np.mean(np.abs(r_rand) >= np.abs(r_obs))
    surrogate_corr_dict[substance]=[r_obs, pv_rand]
    pvals.append(pv_rand)
    print(substance, r_obs, pv_rand)


fdrs=fdrcorrection(pvals)

print(list(zip(list(surrogate_corr_dict.keys()), fdrs[0])))

sns.set_style('ticks')
fig, ax = plt.subplots(figsize=(6,14))

plotting=pd.DataFrame(surrogate_corr_dict).T
spear=list(plotting[0])[::-1]
pval=list(plotting[1])[::-1]
color=['lightskyblue' if x > 0.05 else 'dodgerblue' for x in pval]

ax.barh(range(len(plotting)), width=spear, color=color)
ax.set_yticks(range(len(plotting)))
ax.set_yticklabels(labels_list[::-1])
ax.set_xlabel("spearman's r", fontsize=32)
ax.tick_params(labelsize=32)
plt.tight_layout()
fig.savefig(outpath + 'FIG_3C_barh.jpeg')
plt.close()

# %%
#Supplementary Figure 1
#Use silhouette scores to determine the most appropriate number of centroids for kmeans clustering
"""
Adapted from:
https://scikit-learn.org/stable/auto_examples/cluster/plot_kmeans_silhouette_analysis.html#sphx-glr-auto-examples-cluster-plot-kmeans-silhouette-analysis-py
"""
X=np.log(dd_unified).values

range_n_clusters = [2, 3, 4, 5]

for n_clusters in range_n_clusters:
    fig, ax = plt.subplots(figsize=(8,8))
    ax.set_xlim([0, 1])
    ax.set_ylim([0, len(X) + (n_clusters + 1) * 10])

    clusterer = KMeans(n_clusters=n_clusters, random_state=10)
    cluster_labels = clusterer.fit_predict(X)

    # The silhouette_score gives the average value for all the samples.
    # This gives a perspective into the density and separation of the formed
    # clusters
    silhouette_avg = silhouette_score(X, cluster_labels)

    # Compute the silhouette scores for each sample
    sample_silhouette_values = silhouette_samples(X, cluster_labels)

    y_lower = 10
    for i in range(n_clusters):
        # Aggregate the silhouette scores for samples belonging to
        # cluster i, and sort them
        ith_cluster_silhouette_values = sample_silhouette_values[cluster_labels == i]

        ith_cluster_silhouette_values.sort()

        size_cluster_i = ith_cluster_silhouette_values.shape[0]
        y_upper = y_lower + size_cluster_i

        color = cm.nipy_spectral(float(i) / n_clusters)
        ax.fill_betweenx(
            np.arange(y_lower, y_upper),
            0,
            ith_cluster_silhouette_values,
            facecolor=color,
            edgecolor=color,
            alpha=0.7,
        )

        # Label the silhouette plots with their cluster numbers at the middle
        ax.text(-0.05, y_lower + 0.5 * size_cluster_i, str(i), fontsize=22)

        # Compute the new y_lower for next plot
        y_lower = y_upper + 10  # 10 for the 0 samples

    ax.set_xlabel("Silhouette coefficient values", fontsize=24)

    # The vertical line for average silhouette score of all the values
    lin=ax.axvline(x=silhouette_avg, color="red", linestyle="--")
    lin.set_label(f'{silhouette_avg:.3f}')
    ax.legend(fontsize=22)

    ax.set_yticks([])  # Clear the yaxis labels / ticks
    ax.set_xticks([0, 0.2, 0.4, 0.6, 0.8, 1])
    ax.tick_params(labelsize=22)

    plt.suptitle(" n = %d clusters" % n_clusters,fontsize=28)
    plt.tight_layout()
    fig.savefig(outpath + 'SFIG_1_{}.jpeg'.format(n_clusters))
    plt.close()

# %%
#Supplemental Figure 2
#Plot antidepressant efficacies per cluster and perform correlation analyses between cluster 3 substances' affinity profiles and their antidepressant efficacy
eff=pd.merge(dd_unified, cipriani, left_index=True, right_on='compound')
eff['cluster']=kmeans.labels_
eff=eff[['compound','cluster','efficacy']]
fig, ax=plt.subplots(figsize=(10,10))
color_dict={0 : 'yellow', 1 : 'violet', 2 :'cyan'}
colors=[color_dict[i] for i in kmeans.labels_]
sns.swarmplot(data=eff, x='cluster', y='efficacy', color='black')
sns.boxplot(data=eff, x='cluster', y='efficacy', palette=['cyan', 'y', 'violet'])
ax.set_ylabel('efficacy', fontsize=24)
ax.set_xlabel('cluster', fontsize=24)
ax.set_xticklabels(['1','2','3'], fontsize=22)
ax.tick_params(labelsize=22)
fig.savefig(outpath + 'SFIG_2A.jpeg')
plt.close()

#correlation
combined=dd_unified.merge(eff, left_index=True, right_on='compound')
index=combined['cluster'] == 1
index=index.values
combined=combined[index]
corr, pval=spearmanr(dd_unified[index], combined['efficacy'])
sns.set_style('ticks')
fig, ax = plt.subplots(figsize=(6, 10))
interest=corr[-1][:-1]
color=['lightskyblue' if x > 0.05 else 'dodgerblue' for x in pval[-1][:-1]]
ax.barh(range(len(interest)), width=interest, color=color, linewidth=1)
ax.set_yticks(range(len(interest)))
ax.set_yticklabels(dd_unified.columns)
ax.set_xlabel("spearman's r", fontsize=26)
ax.tick_params(labelsize=26)
plt.tight_layout()
fig.savefig(outpath + 'SFIG_2B.jpeg')
plt.close()

# %%
#Supplementary Figure 5B
#analyse and plot correlational strengths between cortical drug distribution profiles of antidepressants
fig, ax = plt.subplots(figsize=(14,8))
sns.set_theme(font_scale=2.5, style='ticks')
corr=weighted_total_df[['Amitriptyline', 'Clomipramine','Mirtazapine','Nefazodone','Trazodone','Agomelatine','Bupropion',
                   'Reboxetine','Milnacipran','Desvenlafaxine','Fluvoxamine', 'Paroxetine','Sertraline','Duloxetine',
                   'Citalopram','Escitalopram', 'Fluoxetine','Venlafaxine']].corr('spearman')
mask = np.triu(np.ones_like(corr, dtype=bool))
adj_labels=['AMI','CLO','MIR','NEF','TRA','AGO','BUP','REB','MIL','DVEN','FLUV','PAR','SER','DUL','CIT','ECIT','FLUO','VEN']
sns.heatmap(corr, mask=mask, cmap='RdBu_r', vmin=-1, vmax=1, xticklabels=adj_labels, yticklabels=adj_labels)
plt.tight_layout()
fig.savefig(outpath + 'SFIG_5A.jpeg')
plt.close()
